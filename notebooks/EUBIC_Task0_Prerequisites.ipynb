# %% [markdown]
# <a href="https://colab.research.google.com/github/timosachsenberg/EuBIC2026/blob/main/notebooks/EUBIC_Task0_Prerequisites.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install dependencies (for Google Colab)
# !pip install -U pip
# !python -m pip install --pre \
  --extra-index-url https://pypi.openms.de/simple/ \
  pyopenms==3.6.0.dev20260708

import importlib.metadata

print(importlib.metadata.version("pyopenms"))
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (26.1.2)
# Looking in indexes: https://pypi.org/simple, https://pypi.openms.de/simple/
# Requirement already satisfied: pyopenms==3.6.0.dev20260708 in /usr/local/lib/python3.12/dist-packages (3.6.0.dev20260708)
# Requirement already satisfied: numpy>=2.0 in /usr/local/lib/python3.12/dist-packages (from pyopenms==3.6.0.dev20260708) (2.0.2)
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.12/dist-packages (from pyopenms==3.6.0.dev20260708) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5->pyopenms==3.6.0.dev20260708) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5->pyopenms==3.6.0.dev20260708) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5->pyopenms==3.6.0.dev20260708) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5->pyopenms==3.6.0.dev20260708) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5->pyopenms==3.6.0.dev20260708) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5->pyopenms==3.6.0.dev20260708) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5->pyopenms==3.6.0.dev20260708) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5->pyopenms==3.6.0.dev20260708) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5->pyopenms==3.6.0.dev20260708) (1.17.0)
# 3.6.0.dev20260708

# %% [markdown]
# # Notebook 0 – Prerequisites: Python & pyOpenMS Fundamentals
#
# **Welcome to the EuBIC 2026 Winter School!**
#
# This optional notebook covers the foundational concepts you'll need for the main tutorials. It requires some background in Python. Don't worry if you never used Python before. Just team up with someone that has - we are sure you will learn a lot.
#
# ## Who should complete this notebook?
#
# | Your Background | Recommendation |
# |-----------------|----------------|
# | New to Python | Complete Sections 1-3 |
# | Know Python, new to pyOpenMS | Complete Sections 4-5 |
# | Experienced in all | Skip to Notebook 1 |
#
# ## Contents
#
# 1. **Python Essentials** – Variables, lists, dictionaries, functions
# 2. **NumPy Basics** – Arrays and vectorized operations
# 3. **Pandas Basics** – DataFrames for data analysis
# 4. **File Formats** – FASTA, mzML, idXML, featureXML
# 5. **pyOpenMS Object Model** – Core classes and patterns
#
# ---

# %% [markdown]
# # 1. Python Essentials
#
# This section covers the Python basics you'll encounter throughout the tutorials.

# %% [markdown]
# ## 1.1 Variables and Basic Types
#
# Python uses dynamic typing – you don't need to declare variable types.

# %%
# Numbers
mass = 1234.5678       # float (decimal number)
charge = 2             # int (integer)
mz = mass / charge     # arithmetic operations

print(f"Mass: {mass}, Charge: {charge}, m/z: {mz}")
# Out:
# Mass: 1234.5678, Charge: 2, m/z: 617.2839

# %%
# Strings
peptide = "PEPTIDER"   # text in quotes
protein = 'PROTEIN'    # single or double quotes work

# String operations
print(f"Peptide: {peptide}")
print(f"Length: {len(peptide)} amino acids")
print(f"First residue: {peptide[0]}")
print(f"Last residue: {peptide[-1]}")
# Out:
# Peptide: PEPTIDER
# Length: 8 amino acids
# First residue: P
# Last residue: R

# %%
# Booleans
is_tryptic = True
has_modification = False

# Comparisons return booleans
print(f"Is charge > 1? {charge > 1}")
print(f"Is mass < 1000? {mass < 1000}")
# Out:
# Is charge > 1? True
# Is mass < 1000? False

# %% [markdown]
# ## 1.2 Lists
#
# Lists are ordered, mutable collections. You'll use them constantly.

# %%
# Creating lists
masses = [500.25, 600.30, 700.35, 800.40]
amino_acids = ['A', 'R', 'N', 'D', 'C']
empty_list = []

# Accessing elements (0-indexed!)
print(f"First mass: {masses[0]}")
print(f"Last mass: {masses[-1]}")
print(f"First three: {masses[:3]}")
print(f"Last two: {masses[-2:]}")
# Out:
# First mass: 500.25
# Last mass: 800.4
# First three: [500.25, 600.3, 700.35]
# Last two: [700.35, 800.4]

# %%
# Modifying lists
masses.append(900.45)      # Add to end
masses.insert(0, 400.20)   # Insert at position
print(f"After adding: {masses}")

# List information
print(f"Length: {len(masses)}")
print(f"Contains 600.30? {600.30 in masses}")
# Out:
# After adding: [400.2, 500.25, 600.3, 700.35, 800.4, 900.45]
# Length: 6
# Contains 600.30? True

# %%
# Iterating over lists
print("All masses:")
for m in masses:
    print(f"  {m}")

# With index
print("\nWith indices:")
for i, m in enumerate(masses):
    print(f"  [{i}] {m}")
# Out:
# All masses:
#   400.2
#   500.25
#   600.3
#   700.35
#   800.4
#   900.45
#
# With indices:
#   [0] 400.2
#   [1] 500.25
#   [2] 600.3
#   [3] 700.35
#   [4] 800.4
#   [5] 900.45

# %% [markdown]
# ## 1.3 List Comprehensions
#
# A concise way to create lists. You'll see these throughout the tutorials.

# %%
# Traditional loop approach
squared = []
for x in [1, 2, 3, 4, 5]:
    squared.append(x ** 2)
print(f"Squared (loop): {squared}")

# List comprehension - same result, one line
squared = [x ** 2 for x in [1, 2, 3, 4, 5]]
print(f"Squared (comprehension): {squared}")
# Out:
# Squared (loop): [1, 4, 9, 16, 25]
# Squared (comprehension): [1, 4, 9, 16, 25]

# %%
# With filtering
masses = [400, 500, 600, 700, 800, 900, 1000]

# Only masses > 600
large_masses = [m for m in masses if m > 600]
print(f"Large masses: {large_masses}")

# Transform and filter
mz_values = [m / 2 for m in masses if m > 600]  # Assume charge 2
print(f"m/z values (z=2, M>600): {mz_values}")
# Out:
# Large masses: [700, 800, 900, 1000]
# m/z values (z=2, M>600): [350.0, 400.0, 450.0, 500.0]

# %% [markdown]
# ## 1.4 Dictionaries
#
# Key-value pairs for storing related data.

# %%
# Amino acid masses (monoisotopic residue masses)
aa_masses = {
    'A': 71.037,   # Alanine
    'R': 156.101,  # Arginine
    'N': 114.043,  # Asparagine
    'D': 115.027,  # Aspartic acid
    'C': 103.009,  # Cysteine
}

# Accessing values
print(f"Mass of Alanine: {aa_masses['A']} Da")
print(f"Mass of Arginine: {aa_masses['R']} Da")

# Check if key exists
print(f"\nHave mass for 'K'? {'K' in aa_masses}")
# Out:
# Mass of Alanine: 71.037 Da
# Mass of Arginine: 156.101 Da
#
# Have mass for 'K'? False

# %%
# Calculate peptide mass
peptide = "ANDR"
water_mass = 18.011  # H2O lost in peptide bond formation

# Sum residue masses + terminal H and OH
peptide_mass = sum(aa_masses[aa] for aa in peptide) + water_mass
print(f"Mass of {peptide}: {peptide_mass:.3f} Da")
# Out:
# Mass of ANDR: 474.219 Da

# %% [markdown]
# ## 1.5 Functions
#
# Reusable blocks of code.

# %%
def calculate_mz(mass, charge):
    """
    Calculate m/z from mass and charge.

    Parameters:
    -----------
    mass : float
        Neutral mass in Daltons
    charge : int
        Charge state (positive)

    Returns:
    --------
    float : m/z value
    """
    proton_mass = 1.00728
    return (mass + charge * proton_mass) / charge

# Use the function
print(f"m/z of 1000 Da at z=1: {calculate_mz(1000, 1):.4f}")
print(f"m/z of 1000 Da at z=2: {calculate_mz(1000, 2):.4f}")
print(f"m/z of 1000 Da at z=3: {calculate_mz(1000, 3):.4f}")
# Out:
# m/z of 1000 Da at z=1: 1001.0073
# m/z of 1000 Da at z=2: 501.0073
# m/z of 1000 Da at z=3: 334.3406

# %%
# Functions with default parameters
def calculate_mz(mass, charge=2):  # charge defaults to 2
    proton_mass = 1.00728
    return (mass + charge * proton_mass) / charge

print(f"Default z=2: {calculate_mz(1000):.4f}")
print(f"Override z=3: {calculate_mz(1000, charge=3):.4f}")
# Out:
# Default z=2: 501.0073
# Override z=3: 334.3406

# %% [markdown]
# ### Exercise 1.1: Python Basics
#
# Complete the following exercises to test your understanding.

# %%
# Exercise 1.1a: Create a list of peptide sequences
peptides = ["PEPTIDE", "SEQUENCE", "EXAMPLE"]

# TODO: Use a list comprehension to get the lengths of all peptides
# lengths = ???

# Uncomment to check:
# print(f"Lengths: {lengths}")  # Should be [7, 8, 7]

# %%
# Exercise 1.1b: Filter peptides
# TODO: Get only peptides longer than 7 amino acids
# long_peptides = ???

# Uncomment to check:
# print(f"Long peptides: {long_peptides}")  # Should be ['SEQUENCE']

# %% [markdown]
# <details>
# <summary><b>Click for solutions</b></summary>
#
# ```python
# # 1.1a
# lengths = [len(p) for p in peptides]
#
# # 1.1b
# long_peptides = [p for p in peptides if len(p) > 7]
# ```
#
# </details>

# %% [markdown]
# ---
#
# # 2. NumPy Basics
#
# NumPy provides efficient arrays and mathematical operations. It's used extensively in scientific Python.

# %%
import numpy as np

# Creating arrays
masses = np.array([400.2, 500.3, 600.4, 700.5, 800.6])
print(f"Array: {masses}")
print(f"Type: {type(masses)}")
print(f"Shape: {masses.shape}")
# Out:
# Array: [400.2 500.3 600.4 700.5 800.6]
# Type: <class 'numpy.ndarray'>
# Shape: (5,)

# %%
# Vectorized operations (apply to all elements at once)
mz_z2 = masses / 2  # Divide all by 2
print(f"Original masses: {masses}")
print(f"m/z at z=2: {mz_z2}")

# Much faster than loops for large arrays!
# Out:
# Original masses: [400.2 500.3 600.4 700.5 800.6]
# m/z at z=2: [200.1  250.15 300.2  350.25 400.3 ]

# %%
# Useful functions
intensities = np.array([1000, 5000, 2000, 8000, 3000])

print(f"Sum: {np.sum(intensities)}")
print(f"Mean: {np.mean(intensities):.1f}")
print(f"Max: {np.max(intensities)} at index {np.argmax(intensities)}")
print(f"Min: {np.min(intensities)} at index {np.argmin(intensities)}")
# Out:
# Sum: 19000
# Mean: 3800.0
# Max: 8000 at index 3
# Min: 1000 at index 0

# %%
# Boolean indexing (filtering)
high_intensity = intensities > 3000
print(f"Boolean mask: {high_intensity}")
print(f"High intensity values: {intensities[high_intensity]}")
print(f"Corresponding masses: {masses[high_intensity]}")
# Out:
# Boolean mask: [False  True False  True False]
# High intensity values: [5000 8000]
# Corresponding masses: [500.3 700.5]

# %%
# Creating special arrays
zeros = np.zeros(5)
ones = np.ones(5)
range_arr = np.arange(0, 10, 2)  # start, stop, step
linspace = np.linspace(0, 100, 5)  # start, stop, num_points

print(f"Zeros: {zeros}")
print(f"Ones: {ones}")
print(f"Range: {range_arr}")
print(f"Linspace: {linspace}")
# Out:
# Zeros: [0. 0. 0. 0. 0.]
# Ones: [1. 1. 1. 1. 1.]
# Range: [0 2 4 6 8]
# Linspace: [  0.  25.  50.  75. 100.]

# %% [markdown]
# ---
#
# # 3. Pandas Basics
#
# Pandas DataFrames are like spreadsheets in Python. You'll use them to analyze results.

# %%
import pandas as pd

# Creating a DataFrame
data = {
    'peptide': ['PEPTIDER', 'SAMPLER', 'TESTPEPTIDE'],
    'mass': [969.48, 787.40, 1248.59],
    'charge': [2, 2, 3],
    'score': [45.2, 32.1, 58.9]
}

df = pd.DataFrame(data)
df
# Out:
#        peptide     mass  charge  score
# 0     PEPTIDER   969.48       2   45.2
# 1      SAMPLER   787.40       2   32.1
# 2  TESTPEPTIDE  1248.59       3   58.9

# %%
# Accessing columns
print("Peptide column:")
print(df['peptide'])

print("\nMultiple columns:")
print(df[['peptide', 'score']])
# Out:
# Peptide column:
# 0       PEPTIDER
# 1        SAMPLER
# 2    TESTPEPTIDE
# Name: peptide, dtype: object
#
# Multiple columns:
#        peptide  score
# 0     PEPTIDER   45.2
# 1      SAMPLER   32.1
# 2  TESTPEPTIDE   58.9

# %%
# Adding new columns
df['mz'] = (df['mass'] + df['charge'] * 1.00728) / df['charge']
df['length'] = df['peptide'].apply(len)  # Apply function to each row
df
# Out:
#        peptide     mass  charge  score          mz  length
# 0     PEPTIDER   969.48       2   45.2  485.747280       8
# 1      SAMPLER   787.40       2   32.1  394.707280       7
# 2  TESTPEPTIDE  1248.59       3   58.9  417.203947      11

# %%
# Filtering rows
high_score = df[df['score'] > 40]
print("High scoring PSMs:")
high_score
# Out:
# High scoring PSMs:
#        peptide     mass  charge  score          mz  length
# 0     PEPTIDER   969.48       2   45.2  485.747280       8
# 2  TESTPEPTIDE  1248.59       3   58.9  417.203947      11

# %%
# Summary statistics
print(df.describe())
# Out:
#               mass    charge      score          mz     length
# count     3.000000  3.000000   3.000000    3.000000   3.000000
# mean   1001.823333  2.333333  45.400000  432.552836   8.666667
# std     232.289953  0.577350  13.401119   47.421110   2.081666
# min     787.400000  2.000000  32.100000  394.707280   7.000000
# 25%     878.440000  2.000000  38.650000  405.955613   7.500000
# 50%     969.480000  2.000000  45.200000  417.203947   8.000000
# 75%    1109.035000  2.500000  52.050000  451.475613   9.500000
# max    1248.590000  3.000000  58.900000  485.747280  11.000000

# %%
# Iterating over rows
print("All PSMs:")
for idx, row in df.iterrows():
    print(f"  {row['peptide']}: score={row['score']}, m/z={row['mz']:.2f}")
# Out:
# All PSMs:
#   PEPTIDER: score=45.2, m/z=485.75
#   SAMPLER: score=32.1, m/z=394.71
#   TESTPEPTIDE: score=58.9, m/z=417.20

# %% [markdown]
# ---
#
# # 4. File Formats
#
# Common file formats you'll encounter in proteomics.
#
# ## 4.1 OpenMS File Formats
#
# | Format | Extension | Contains |
# |--------|-----------|----------|
# | **idXML** | `.idXML` | Peptide/protein identifications from database search |
# | **featureXML** | `.featureXML` | Detected features with quantitative information |
# | **consensusXML** | `.consensusXML` | Features aligned across multiple samples |

# %% [markdown]
# ---
#
# # 5. pyOpenMS Object Model
#
# pyOpenMS provides Python bindings to OpenMS, a C++ library for computational mass spectrometry.
#
# **Online Documentation:**
# - [pyOpenMS Documentation](https://pyopenms.readthedocs.io/en/latest/user_guide/index.html) – Official docs with tutorials and API
# - advanced: [OpenMS C++ Class Reference](https://abibuilder.cs.uni-tuebingen.de/archive/openms/Documentation/nightly/html/index.html) – Detailed API reference

# %%
import pyopenms as oms
print(f"pyOpenMS version: {oms.__version__}")
# Out:
# pyOpenMS version: 3.6.0.dev20260708

# %% [markdown]
# ## 5.1 Getting Help and Documentation
#
# pyOpenMS has extensive documentation. Here's how to explore it:

# %%
# List all available methods on a class using dir()
# Filter to show only public methods (not starting with '_')
spectrum = oms.MSSpectrum()
public_methods = [m for m in dir(spectrum) if not m.startswith('_')]
print("MSSpectrum methods (first 15):")
print(public_methods[:15])
# Out:
# MSSpectrum methods (first 15):
# ['MSSpectrumRasterAggregation', 'calculateTIC', 'clear', 'clearMetaInfo', 'clearRanges', 'containsIMData', 'df_columns', 'findHighestInWindow', 'findNearest', 'getAcquisitionInfo', 'getAllNamesOfSpectrumType', 'getComment', 'getDataProcessing', 'getDriftTime', 'getDriftTimeUnit']

# %%
# Get documentation for a specific method using help()
# This shows the docstring with parameter info and return types
help(spectrum.setRT)
# Out:
# Help on nb_bound_method in module pyopenms._pyopenms_spectrum object:
#
# setRT = class nb_bound_method(builtins.object)
#  |  Methods defined here:
#  |
#  |  __call__(self, /, *args, **kwargs)
#  |      Call self as a function.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __func__
#  |
#  |  __self__
#  |
#  |  __vectorcalloffset__

# %%
# show the full help
help(oms.AASequence)
# Out:
# Help on class AASequence in module pyopenms._pyopenms_chemistry:
#
# class AASequence(builtins.object)
#  |  AASequence(*args, **kwargs)
#  |
#  |  Representation of a peptide/protein sequence
#  |  This class represents amino acid sequences in OpenMS. An AASequence
#  |  instance primarily contains a sequence of residues.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(...)
#  |      __add__(self, arg: pyopenms._pyopenms_chemistry.AASequence, /) -> pyopenms._pyopenms_chemistry.AASequence
#  |
#  |  __copy__(...)
#  |      __copy__(self) -> pyopenms._pyopenms_chemistry.AASequence
#  |
#  |  __deepcopy__(...)
#  |      __deepcopy__(self, memo: dict) -> pyopenms._pyopenms_chemistry.AASequence
#  |
#  |  __eq__(...)
#  |      __eq__(self, arg: pyopenms._pyopenms_chemistry.AASequence, /) -> bool
#  |
#  |  __getitem__(...)
#  |      __getitem__(self, arg: int, /) -> pyopenms._pyopenms_chemistry.Residue
#  |
#  |  __hash__(...)
#  |      __hash__(self) -> int
#  |
#  |  __iadd__(...)
#  |      __iadd__(self, rhs: pyopenms._pyopenms_chemistry.AASequence) -> pyopenms._pyopenms_chemistry.AASequence
#  |
#  |      In-place concatenation of sequences
#  |
#  |  __init__(...)
#  |      __init__(self) -> None
#  |      __init__(self, arg: pyopenms._pyopenms_chemistry.AASequence) -> None
#  |      __init__(self, sequence: str) -> None
#  |      __init__(self, arg: str, /) -> None
#  |      __init__(self, arg0: str, arg1: bool, /) -> None
#  |
#  |      Overloaded function.
#  |
#  |      1. ``__init__(self) -> None``
#  |
#  |      Default constructor - creates empty sequence
#  |
#  |      2. ``__init__(self, arg: pyopenms._pyopenms_chemistry.AASequence) -> None``
#  |
#  |      Copy constructor
#  |
#  |      3. ``__init__(self, sequence: str) -> None``
#  |
#  |      Create AASequence from string (e.g., 'PEPTIDE')
#  |
#  |      4. ``__init__(self, arg: str, /) -> None``
#  |
#  |
#  |      5. ``__init__(self, arg0: str, arg1: bool, /) -> None``
#  |
#  |  __iter__(...)
#  |      __iter__(self) -> collections.abc.Iterator[pyopenms._pyopenms_chemistry.Residue]
#  |
#  |  __len__(...)
#  |      __len__(self) -> int
#  |
#  |  __ne__(...)
#  |      __ne__(self, arg: pyopenms._pyopenms_chemistry.AASequence, /) -> bool
#  |
#  |  __repr__(...)
#  |      __repr__(self) -> str
#  |
#  |  __str__(...)
#  |      __str__(self) -> str
#  |
#  |  empty(...)
#  |      empty(self) -> bool
#  |
#  |      Check if sequence is empty
#  |
#  |  getAAFrequencies(...)
#  |      getAAFrequencies(self) -> dict[str, int]
#  |
#  |      Returns the amino acid frequencies of the peptide
#  |
#  |  getAverageWeight(...)
#  |      getAverageWeight(self) -> float
#  |      getAverageWeight(self, type: pyopenms._pyopenms_chemistry.Residue.ResidueType, charge: int) -> float
#  |
#  |      Overloaded function.
#  |
#  |      1. ``getAverageWeight(self) -> float``
#  |
#  |      Returns the average weight of the peptide
#  |
#  |      2. ``getAverageWeight(self, type: pyopenms._pyopenms_chemistry.Residue.ResidueType, charge: int) -> float``
#  |
#  |      Returns the average weight of the peptide with specified residue type and charge
#  |
#  |  getCTerminalModification(...)
#  |      getCTerminalModification(self) -> pyopenms._pyopenms_chemistry.ResidueModification
#  |
#  |      Returns a copy of the name C-terminal modification object, or None
#  |
#  |  getCTerminalModificationName(...)
#  |      getCTerminalModificationName(self) -> str
#  |
#  |      Returns the name (ID) of the C-terminal modification, or an empty string if none is set
#  |
#  |  getFormula(...)
#  |      getFormula(self) -> pyopenms._pyopenms_chemistry.EmpiricalFormula
#  |      getFormula(self, type: pyopenms._pyopenms_chemistry.Residue.ResidueType, charge: int) -> pyopenms._pyopenms_chemistry.EmpiricalFormula
#  |
#  |      Overloaded function.
#  |
#  |      1. ``getFormula(self) -> pyopenms._pyopenms_chemistry.EmpiricalFormula``
#  |
#  |      Returns the empirical formula of the peptide
#  |
#  |      2. ``getFormula(self, type: pyopenms._pyopenms_chemistry.Residue.ResidueType, charge: int) -> pyopenms._pyopenms_chemistry.EmpiricalFormula``
#  |
#  |      Returns the empirical formula of the peptide with specified residue type and charge
#  |
#  |  getMZ(...)
#  |      getMZ(self, charge: int) -> float
#  |      getMZ(self, charge: int, type: pyopenms._pyopenms_chemistry.Residue.ResidueType) -> float
#  |
#  |      Overloaded function.
#  |
#  |      1. ``getMZ(self, charge: int) -> float``
#  |
#  |      Returns the mass-to-charge ratio of the peptide
#  |
#  |      2. ``getMZ(self, charge: int, type: pyopenms._pyopenms_chemistry.Residue.ResidueType) -> float``
#  |
#  |      Returns the mass-to-charge ratio of the peptide with specified residue type
#  |
#  |  getMonoWeight(...)
#  |      getMonoWeight(self) -> float
#  |      getMonoWeight(self, type: pyopenms._pyopenms_chemistry.Residue.ResidueType, charge: int) -> float
#  |
#  |      Overloaded function.
#  |
#  |      1. ``getMonoWeight(self) -> float``
#  |
#  |      Returns the monoisotopic weight of the peptide
#  |
#  |      2. ``getMonoWeight(self, type: pyopenms._pyopenms_chemistry.Residue.ResidueType, charge: int) -> float``
#  |
#  |      Returns the monoisotopic weight of the peptide with specified residue type and charge
#  |
#  |  getNTerminalModification(...)
#  |      getNTerminalModification(self) -> pyopenms._pyopenms_chemistry.ResidueModification
#  |
#  |      Returns a copy of the name N-terminal modification object, or None
#  |
#  |  getNTerminalModificationName(...)
#  |      getNTerminalModificationName(self) -> str
#  |
#  |      Returns the name (ID) of the N-terminal modification, or an empty string if none is set
#  |
#  |  getPrefix(...)
#  |      getPrefix(self, index: int) -> pyopenms._pyopenms_chemistry.AASequence
#  |
#  |      Returns a peptide sequence of the first index residues
#  |
#  |  getResidue(...)
#  |      getResidue(self, index: int) -> pyopenms._pyopenms_chemistry.Residue
#  |
#  |      Returns the residue at position index
#  |
#  |  getSubsequence(...)
#  |      getSubsequence(self, index: int, number: int) -> pyopenms._pyopenms_chemistry.AASequence
#  |
#  |      Returns a peptide sequence of number residues, beginning at position index
#  |
#  |  getSuffix(...)
#  |      getSuffix(self, index: int) -> pyopenms._pyopenms_chemistry.AASequence
#  |
#  |      Returns a peptide sequence of the last index residues
#  |
#  |  has(...)
#  |      has(self, residue: pyopenms._pyopenms_chemistry.Residue) -> bool
#  |
#  |      Returns true if the peptide contains the given residue
#  |
#  |  hasCTerminalModification(...)
#  |      hasCTerminalModification(self) -> bool
#  |
#  |      Predicate which is true if the peptide is C-term modified
#  |
#  |  hasNTerminalModification(...)
#  |      hasNTerminalModification(self) -> bool
#  |
#  |      Predicate which is true if the peptide is N-term modified
#  |
#  |  hasPrefix(...)
#  |      hasPrefix(self, peptide: pyopenms._pyopenms_chemistry.AASequence) -> bool
#  |
#  |      Returns true if the peptide has the given prefix
#  |
#  |  hasSubsequence(...)
#  |      hasSubsequence(self, peptide: pyopenms._pyopenms_chemistry.AASequence) -> bool
#  |
#  |      Returns true if the peptide contains the given peptide
#  |
#  |  hasSuffix(...)
#  |      hasSuffix(self, peptide: pyopenms._pyopenms_chemistry.AASequence) -> bool
#  |
#  |      Returns true if the peptide has the given suffix
#  |
#  |  isModified(...)
#  |      isModified(self) -> bool
#  |
#  |      Returns true if any of the residues or termini are modified
#  |
#  |  setCTerminalModification(...)
#  |      setCTerminalModification(self, modification: str) -> None
#  |      setCTerminalModification(self, modification: pyopenms._pyopenms_chemistry.ResidueModification) -> None
#  |      setCTerminalModification(self, mod: pyopenms._pyopenms_chemistry.ResidueModification) -> None
#  |
#  |      Sets the C-terminal modification (by lookup in the mod names of the ModificationsDB). Throws if nothing is found (since the name is not enough information to create a new mod)
#  |
#  |  setCTerminalModificationByDiffMonoMass(...)
#  |      setCTerminalModificationByDiffMonoMass(self, diffMonoMass: float, protein_term: bool) -> None
#  |
#  |      Sets the C-terminal modification by the monoisotopic mass difference it introduces (creates a "user-defined" mod if not present)
#  |
#  |  setModification(...)
#  |      setModification(self, index: int, modification: str) -> None
#  |      setModification(self, index: int, modification: pyopenms._pyopenms_chemistry.Residue) -> None
#  |      setModification(self, index: int, modification: pyopenms._pyopenms_chemistry.ResidueModification) -> None
#  |      setModification(self, index: int, modification: pyopenms._pyopenms_chemistry.ResidueModification) -> None
#  |
#  |      Sets the modification of the residue at position index. If an empty string is passed replaces the residue with its unmodified version
#  |
#  |  setModificationByDiffMonoMass(...)
#  |      setModificationByDiffMonoMass(self, index: int, diffMonoMass: float) -> None
#  |
#  |      Modifies the residue at index in the sequence and potentially in the ResidueDB
#  |
#  |  setNTerminalModification(...)
#  |      setNTerminalModification(self, modification: str) -> None
#  |      setNTerminalModification(self, modification: pyopenms._pyopenms_chemistry.ResidueModification) -> None
#  |      setNTerminalModification(self, mod: pyopenms._pyopenms_chemistry.ResidueModification) -> None
#  |
#  |      Sets the N-terminal modification (by lookup in the mod names of the ModificationsDB). Throws if nothing is found (since the name is not enough information to create a new mod)
#  |
#  |  setNTerminalModificationByDiffMonoMass(...)
#  |      setNTerminalModificationByDiffMonoMass(self, diffMonoMass: float, protein_term: bool) -> None
#  |
#  |      Sets the N-terminal modification by the monoisotopic mass difference it introduces (creates a "user-defined" mod if not present)
#  |
#  |  size(...)
#  |      size(self) -> int
#  |
#  |      Returns the number of residues
#  |
#  |  toBracketString(...)
#  |      toBracketString(self, integer_mass: bool = True, mass_delta: bool = False, fixed_modifications: list[str] = []) -> str
#  |
#  |      Returns the bracket string representation of the peptide
#  |
#  |  toString(...)
#  |      toString(self) -> str
#  |
#  |      Returns the peptide as string with modifications embedded in brackets
#  |
#  |  toUniModString(...)
#  |      toUniModString(self) -> str
#  |
#  |      Returns the peptide as string with UniMod-style modifications embedded in brackets
#  |
#  |  toUnmodifiedString(...)
#  |      toUnmodifiedString(self) -> str
#  |
#  |      Returns the peptide as string without any modifications
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  fromString = <nanobind.nb_func object>
#  |      fromString(s: str) -> pyopenms._pyopenms_chemistry.AASequence
#  |
#  |      Create AASequence from string (deprecated - use AASequence(s) constructor)
#  |
#  |
#  |  fromStringPermissive = <nanobind.nb_func object>
#  |      fromStringPermissive(s: str, permissive: bool) -> pyopenms._pyopenms_chemistry.AASequence
#  |
#  |      Create AASequence from string with permissive mode

# %% [markdown]
# ## 5.2 Common Pattern: Load → Process → Save

# %%
# The standard pyOpenMS workflow pattern:

# 1. Create empty container
exp = oms.MSExperiment()

# 2. Load data from file
# oms.MzMLFile().load("data.mzML", exp)

# 3. Process data
# ... (e.g., feature detection, filtering)

# 4. Save results
# oms.MzMLFile().store("output.mzML", exp)

print("Pattern: Create → Load → Process → Save")
# Out:
# Pattern: Create → Load → Process → Save

# %% [markdown]
# ## 5.3 Working with Algorithms

# %%
# Most algorithms follow this pattern:

# 1. Create algorithm instance
tsg = oms.TheoreticalSpectrumGenerator()

# 2. Get and modify parameters
params = tsg.getParameters()
params.setValue("add_b_ions", "true")
params.setValue("add_y_ions", "true")
tsg.setParameters(params)

# 3. Run the algorithm
peptide = oms.AASequence("PEPTIDER")
theo_spectrum = oms.MSSpectrum()
tsg.getSpectrum(theo_spectrum, peptide, 1, 2)  # charge 1 to 2

print(f"Generated {theo_spectrum.size()} theoretical peaks")
# Out:
# Generated 26 theoretical peaks
